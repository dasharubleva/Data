# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

# %%
data_path = '../content/drive/MyDrive/supermarket_sales.csv'
df = pd.read_csv(data_path)

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
groupbyBranch = df.groupby('Branch')['Total'].sum().round(3)
groupbyBranch.sort_values(ascending=False)
# Out:
# Branch
# C    110568.706
# A    106200.370
# B    106197.672
# Name: Total, dtype: float64

# %% [markdown]
# Найвищий прибуток має філіал С.

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df[df['Branch'] == 'C']
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 20   300-71-4605      C  Naypyitaw        Member    Male
# 34   183-56-6882      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 5    Electronic accessories       85.39         7  29.8865  627.6165
# 7        Home and lifestyle       73.56        10  36.7800  772.3800
# ...

# %% [markdown]
# Філіал з найвищим прибутком знаходиться в місті Naypyitaw.

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
from numpy._core.defchararray import count
invoices_by_category = df.pivot_table(index= 'Branch', columns='Product line',values='Quantity',aggfunc="count")
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category['Electronic accessories'].idxmax()
# Out:
# 'A'

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# 1.Пошук та ідентифікація віп клієнів по містам.
# Рекомендації:
# - створення відділу по роботі з віп клієнтами.
# - нова сегментація по загальній кількості покупок.
# - індивідуальний підхід та вивчення потреб клієнта.
# - закріплення персональних менеджерів за клієнтами.
# - передбачення їх потреб.
# - високий рівень сервісу та турботи.
# - спеціальні умови та пропозиції
# - швидкість , вирішення проблем у максимально швидкий термін.

# %%
df.sort_values(by = ['Total', 'City'], ascending=False).head(15)
#pivot_total = pd.pivot_table(df, index='Customer type', columns='City', values='Total',aggfunc=max)
#pivot_total
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 350  860-79-0874      C  Naypyitaw        Member  Female
# 167  687-47-8271      A     Yangon        Normal    Male
# 557  283-26-5248      C  Naypyitaw        Member  Female
# 699  751-41-9720      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 792  744-16-7898      B   Mandalay        Normal  Female
# 422  271-88-8734      C  Naypyitaw        Member  Female
# 166  234-65-2137      C  Naypyitaw        Normal    Male
# 357  554-42-2417      C  Naypyitaw        Normal  Female
# 429  325-77-6186      A     Yangon        Member  Female
# 141  280-17-4359      C  Naypyitaw        Member    Male
# 122  219-22-9386      B   Mandalay        Member    Male
# 941  702-83-5291      C  Naypyitaw        Member    Male
# 140  731-81-9469      C  Naypyitaw        Member  Female
# 209  817-69-8206      B   Mandalay        Normal  Female
#
# ...

# %% [markdown]
# 2. Яка кількість клієнтів є Normal,а яка Member - по містам?
# Провіши дослідження ми побачили, що клієнти Member та Normal розділені близько 50% на 50%.
# Нагадаю, що тип клієнтів діляються: Member -  що використовують картку члена, та Normal - звичайні без картки.
# Хочу запровадити певне заохочення, щоб наші клієнти хотіли статати членами, що мають нашу особливу картку.
# Рекомендації та дії:
# - запровадити накопичувальну персоналізовану систему для наших клієнтів, пізніше вони зможуть використати ці бали в нашому магазині або магазинах партнерів  і будуть повертатися та намагатися здійснити покупки у нас.
# - створення додатку для членів, що мають карту, щоб була змога комунікувати з нашим клієнтом.
# - сповіщення про дегустації, акції, оновлення, персональні пропозиції через додатки.
# - створення лояльних покупців в нашому ком'юніті - додатку.
# - додаткові бали та знижки на День Народження.
# - якщо наш клієнт немає карти - пропонувати її на касах ,якщо клієнт має контакт з касиром,або через самокаси - показувати скільки він міг би заощадити , використовуючи карту.

# %%
CustomerType_pivot = pd.pivot_table(df, index='Customer type', columns='City', values='Invoice ID',aggfunc=pd.Series.nunique)
CustomerType_pivot
# Out:
# City           Mandalay  Naypyitaw  Yangon
# Customer type
# Member              165        169     167
# Normal              167        159     173

# %%
CustomerType_pivot.sum(axis=0)
# Out:
# City
# Mandalay     332
# Naypyitaw    328
# Yangon       340
# dtype: int64

# %%
perc_CustomerType_pivot = CustomerType_pivot.div(CustomerType_pivot.sum(axis=0), axis=1).round(3) * 100
perc_CustomerType_pivot
# Out:
# City           Mandalay  Naypyitaw  Yangon
# Customer type
# Member             49.7       51.5    49.1
# Normal             50.3       48.5    50.9

# %% [markdown]
# 3. В який з місяців купують найбільше? Чи рівномірний попит?
# Зробивши аналіз за три місяці роботи ми бачимо,що за:
#
# - січень - 35.3%
# - лютий - 30.3%
# - березень - 34.5%
#
# Найбільший попит ми помітили в січні та майже на тому ж рівні березень. Можу зробити припущення, що в січні багато наших клієнтів відпочиває, школярі мають канікули і кількість покупок вища.
# В березні попит тримається на рівні січня, березневі свята та покращення погодних умов можуть впливати на це.
# В лютому найменше днів , що звісно впливає на відсоткове співвідношення. Та ймовірно продажі просіли.
#
# Рекомендації:
# - відслідковання динаміки продажів щомісячно.
# - аналіз з попердніми місяцями та історичними показниками попередніх років.
# - плануваня акцій на лютий місяць.
# - активна комунікація з клієнтом в наших соцмережах , через додаток.
# - активна увагам до наших віп клієнтів.

# %%
def get_month(date_str):
  date = pd.to_datetime(date_str,format= '%m/%d/%Y')
  return date.month

# %%
df['Month'] = df['Date'].apply(get_month)

# %%
month_3 = df.groupby('Month')['Month'].count()
month_3
# Out:
# Month
# 1    352
# 2    303
# 3    345
# Name: Month, dtype: int64

# %%
month_3/month_3.sum() * 100
# Out:
# Month
# 1    35.2
# 2    30.3
# 3    34.5
# Name: Month, dtype: float64
